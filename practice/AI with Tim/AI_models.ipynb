# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #**Loading data**#

# %%
data = keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels) = data.load_data()

# %% [markdown]
# #**Showing a training picture**

# %%
plt.imshow(train_images[3], cmap=plt.cm.binary)
plt.show()

# %% [markdown]
# # **Getting a picture in binary form**

# %%
print(train_images[4])

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
print(train_labels[3])
# Out:
# 0

# %%
train_images/255.0
test_images/255.0

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(300,activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model.fit(train_images,train_labels,epochs=5)
test_loss,test_acc = model.evaluate(test_images,test_labels)

print("Accurancy is: ", test_acc)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.6410 - accuracy: 0.7306
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5814 - accuracy: 0.7998
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5333 - accuracy: 0.8196
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5100 - accuracy: 0.8249
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4906 - accuracy: 0.8331
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5212 - accuracy: 0.8140
# Accurancy is:  0.8140000104904175
