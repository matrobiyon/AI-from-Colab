# %%
# !git config --global user.name "matrobiyon"
# !git config --global user.email "matrobovqosim@gmail.com"
# !git config --global user.password "qosim..00"

# %%
token = "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"
username = "matrobiyon"
repo = "AI-from-Colab"

# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'AI-from-Colab'...
# ...

# %%
# %cd {repo}
# Out:
# /root/AI-from-Colab

# %%
# %ls

# %%
# !mv /content/drive/MyDrive/practice /root/AI-from-Colab
# Out:
# mv: cannot stat '/content/drive/MyDrive/practice': No such file or directory

# %%
# %cd {repo}
# Out:
# [Errno 2] No such file or directory: '{repo}'
# /root
